# %%
from dataloader.sintelloader3d import SintelLoader3D

# %%
loader = SintelLoader3D()

# %%
train = loader.train()

# %%
sample = next(iter(train))

# %%
frame = sample['frame']
flow = sample['flow']

# %%
sample['occlusion'].shape
# Out:
# torch.Size([1, 1, 9, 260, 256])

# %%
frame.shape
# Out:
# torch.Size([1, 3, 10, 260, 256])

# %%
flow.shape
# Out:
# torch.Size([1, 2, 9, 260, 256])

# %%
from torchvision.transforms import ToPILImage

# %%
ToPILImage()(frame[0,:,4,:])
# Out:
# <PIL.Image.Image image mode=RGB size=256x260 at 0x7F77503C80B8>

# %%
from utils import flow2rgb
import torch

# %%
flow.shape
# Out:
# torch.Size([20, 2, 9, 260, 256])

# %%
sf = flow[0:1,:,0,:]
# sf_ = sf * torch.tensor([436., 1024.]).view(1, 2, 1, 1)

# %%
ToPILImage()(flow2rgb(sf)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=256x260 at 0x7F76131AD240>

# %%
import random
random.randint(0,436-256),random.randint(0,1024-256)
# Out:
# (119, 142)

# %%
hstart = random.randint(0,436-256)
wstart = random.randint(0,1024-256)

hend = hstart + 256
wend = wstart + 256
ToPILImage()(frame[0][:,0,hstart:hend,wstart:wend])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAA098270B8>

# %%
from models.Pyramid3dnet import PyramidUNet

# %%
m = PyramidUNet()

# %%
import torch
out = m(torch.rand(1,3,10,260,256))

# %%
a,b,c,d = out

# %%
a1,a2 = a
b1,b2 = b
c1,c2 = c
d1,d2 = d

# %%
a1.shape
# Out:
# torch.Size([1, 2, 9, 260, 256])

# %%
b1.shape
# Out:
# torch.Size([1, 2, 9, 64, 64])

# %%
c1.shape
# Out:
# torch.Size([1, 2, 9, 32, 32])

# %%
d1.shape
# Out:
# torch.Size([1, 2, 9, 16, 16])
